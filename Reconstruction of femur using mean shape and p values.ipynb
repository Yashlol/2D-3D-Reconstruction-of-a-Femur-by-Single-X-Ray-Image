# %%
import os
import trimesh
import numpy as np

# %%
mesh_folder = r"C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\Visualization_of_p_values\mean_shape.stl"

# %%
template_mesh = trimesh.load(mesh_folder)

template_vertices = template_mesh.vertices

template_faces = template_mesh.faces

print(template_vertices.shape)
print(template_faces.shape)
# Out:
# (24431, 3)
# (48718, 3)

# %%
mean_shape=np.load(r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\mean_shape.npy')

mean_shape.shape
# Out:
# (73293,)

# %%
import numpy as np

location1 =r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\eigenvectors.npy'
data = np.load(location1)
eigenvectors = data[:5]
# Print the array contents
print(eigenvectors)
# Out:
# [[-0.00042662 -0.00240114 -0.00681031 ... -0.00042873  0.0022811
#    0.01085113]
#  [ 0.00333708 -0.00832499 -0.00391668 ... -0.0033604  -0.00070032
#    0.00105163]
#  [ 0.00725902  0.00401192 -0.00456556 ... -0.00179843 -0.01220611
#   -0.00104283]
#  [ 0.01019132 -0.00064115 -0.00095295 ...  0.0095454   0.01370144
#    0.0043609 ]
#  [ 0.0041367   0.00354933  0.00665366 ... -0.00879889 -0.00927068
#   -0.0027694 ]]

# %%
import numpy as np

location2 =r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\sigma.npy'
data = np.load(location2)
sigma = data[:5]

# Print the array contents
print(sigma)
# Out:
# [1853.54425145  405.83531725  307.3041873   247.18201026  177.58565124]

# %%
p = np.array([
    0.851316,
    0.850527,
    -1.962240,
    -1.785992, 
    -0.223065
])

# %%
reconstructed_shape = mean_shape.copy()

# %%
for i in range(5):
    
    reconstructed_shape += (
        p[i]
        *
        sigma[i]
        *
        eigenvectors[i]
    )

# %%
vertices = reconstructed_shape.reshape(-1,3)

# %%
mesh = trimesh.Trimesh(
    vertices=vertices,
    faces=template_mesh.faces
)

# %%
mesh.export(
    "test_femur.stl"
)
# Out:
# b'N\xbe\x00\x00z\x81B\xbe\xe3xK\xbfd\x8c\x13\xbf\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\x11f\xa2C\x18\x1d\x18C\xa1\x019D\x96)\xa2C(\x81\x18C\x19\xe98D\x00\x00\x1c\xbd\x00>\x90\xb7H\xbf\xcd\x9a\x1b\xbf\xff\x8c\xa2C-\x89\x18C\xf3\xd58D^\x11\xa3C\xb5l\x18C\xd2\xec8D\x0c\xd0\xa2C\x92\x00\x18C\xf0\x089D\x00\x00\x9e\xe8\x1f\xbd\x1e\x86W\xbf\xc2\xc9\t\xbf\x11f\xa2C\x18\x1d\x18C\xa1\x019D\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\x0c\xd0\xa2C\x92\x00\x18C\xf0\x089D\x00\x00\xde\xc0V>\x03\xa8P\xbf\xd2B\n\xbf\x0c\xd0\xa2C\x92\x00\x18C\xf0\x089D^\x11\xa3C\xb5l\x18C\xd2\xec8D\xee7\xa3C\xce\x14\x18Cy\x159D\x00\x00\xa3\xe7\x08\xbf\xdc\xf6!\xbf\xc9c\x0f\xbf\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\xcc\xdb\xa1C\x82\xc7\x18C\xb6\xee8DB\xae\xa1CdC\x19Cw\xe18D\x00\x00\xfa\xa2\xd1\xbeD>;\xbfu\x9a\x0b\xbf\x96)\xa2C(\x81\x18C\x19\xe98D\xcc\xdb\xa1C\x82\xc7\x18C\xb6\xee8D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\x00\x00\x1d\x14Z\xbe\xf2\xf7>\xbf\xcf\x89!\xbf\x96)\xa2C(\x81\x18C\x19\xe98D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\x00\x00w\xf4v\xbe\x13\x14E\xbf\xa7F\x17\xbf\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\xfb}\xa2C\xe7\x13\x19C\xd5\xab8D\x00\x00\xb0\'\x10>\xe9\xf2@\xbfGW$\xbf^\x11\xa3C\xb5l\x18C\xd2\xec8D\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\x00\x002f\x0e>\xd7\x8d@\xbf\x13\xe6$\xbf\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\xff\x8c\xa2C-\x89\x18C\xf3\xd58D\xfb}\xa2C\xe7\x13\x19C\xd5\xab8D\x00\x00OD\xc3>\x1d\xb39\xbf\xdb\xb1\x12\xbf|i\xa3C#l\x18CS\n9D\xee7\xa3C\xce\x14\x18Cy\x159D^\x11\xa3C\xb5l\x18C\xd2\xec8D\x00\x00\x16\xf3\xed>\x9a\xe9\x0b\xbfHW2\xbf|i\xa3C#l\x18CS\n9D^\x11\xa3C\xb5l\x18C\xd2\xec8D\x9fa\xa3C\xa1\xe9\x18C\x17\xef8D\x00\x00\xac\xca\xf6>\xde0\x12\xbf^\x1c*\xbf\x9fa\xa3C\xa1\xe9\x18C\x17\xef8D^\x11\xa3C\xb5l\x18C\xd2\xec8D\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\x00\x00\xf1\xb7\x1d?c\x1d\xf1\xbeH\xa3!\xbf|i\xa3C#l\x18CS\n9D\x9fa\xa3C\xa1\xe9\x18C\x17\xef8DX\xa6\xa3C\xa4\xb3\x18C\xaf\x1a9D\x00\x00\xf0S>\xbf\x82\xd4n\xbe\xe2t \xbf\x1b\xaa\xa1C\xe5\xe3\x19C1\xc98D\xb9n\xa1C)\xa4\x19CW\xf28D*U\xa1CzM\x1aC\xc0\xf18D\x00\x00\xb21\'\xbfp3\xd5\xbe\xd2\xeb!\xbfB\xae\xa1CdC\x19Cw\xe18D\xb9n\xa1C)\xa4\x19CW\xf28D\x1b\xaa\xa1C\xe5\xe3\x19C1\xc98D\x00\x00\xf2\x9a\x16\xbf\x1e\x98\xe1\xbe\x1c\x95-\xbfB\xae\xa1CdC\x19Cw\xe18D\x1b\xaa\xa1C\xe5\xe3\x19C1\xc98D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\x00\x00\nL\x17\xbf\x9f~\xe3\xbeC[,\xbf\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\x1b\xaa\xa1C\xe5\xe3\x19C1\xc98D\xab\xfc\xa1C\x17\xdb\x19Ci\xa68D\x00\x00\xa5\xb7\x97\xbe\xa8~\x03\xbf\xe9!N\xbf\xfb}\xa2C\xe7\x13\x19C\xd5\xab8D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\xcaR\xa2C\x84\x9e\x19C\xac\x9d8D\x00\x008\x8f\xaa\xbe\xf7\x14\xf5\xbe\x97\xf5O\xbf\xcaR\xa2C\x84\x9e\x19C\xac\x9d8D\xab\n\xa2C\xd1!\x19C\xd5\xbe8D\xab\xfc\xa1C\x17\xdb\x19Ci\xa68D\x00\x00\xa6x\x9f>)\xb0\xb9\xbe\xfe\xd9`\xbf\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\xfb}\xa2C\xe7\x13\x19C\xd5\xab8D\xd5\xc3\xa2C,\x84\x19C\xa1\xac8D\x00\x00\x1e\xfba>\x8b\xd0}\xbe\xb5}q\xbf\xd5\xc3\xa2C,\x84\x19C\xa1\xac8D\xfb}\xa2C\xe7\x13\x19C\xd5\xab8D\xcaR\xa2C\x84\x9e\x19C\xac\x9d8D\x00\x00\xefV\x10?p\xc9\x96\xbe\x8f\x87E\xbf\x9fa\xa3C\xa1\xe9\x18C\x17\xef8D\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\xa7(\xa3C\xd6h\x19C#\xce8D\x00\x00\x93l\x04?!\xefi\xbe\x7f#S\xbf\xa7(\xa3C\xd6h\x19C#\xce8D\xb2\xe9\xa2CO\xec\x18C\x04\xc38D\xd5\xc3\xa2C,\x84\x19C\xa1\xac8D\x00\x00\xd4\xb01?\x18\xff\xa2\xbe\xaaI%\xbf`\xba\xa3C\xe1#\x19C\x9e\x179DX\xa6\xa3C\xa4\xb3\x18C\xaf\x1a9D\x9fa\xa3C\xa1\xe9\x18C\x17\xef8D\x00\x00\x03\xdc-?\xb7h\xe8\xbc\'\xc4;\xbf`\xba\xa3C\xe1#\x19C\x9e\x179D\x9fa\xa3C\xa1\xe9\x18C\x17\xef8Dm\x8e\xa3Cp\xa6\x19C\x02\x029D\x00\x00\x85\xda8?-\xaf\x88\xbd\xa9F0\xbfm\x8e\xa3Cp\xa6\x19C\x02\x029D\x9fa\xa3C\xa1\xe9\x18C ...
