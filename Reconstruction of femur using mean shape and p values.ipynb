# %%
import os
import trimesh
import numpy as np

# %%
mesh_folder = r"C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\Visualization_of_p_values\mean_shape.stl"

# %%
template_mesh = trimesh.load(mesh_folder)

template_vertices = template_mesh.vertices

template_faces = template_mesh.faces

print(template_vertices.shape)
print(template_faces.shape)
# Out:
# (24431, 3)
# (48718, 3)

# %%
mean_shape=np.load(r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\mean_shape.npy')

mean_shape.shape
# Out:
# (73293,)

# %%
import numpy as np

location1 =r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\eigenvectors.npy'
data = np.load(location1)
eigenvectors = data[:5]

# Print the array contents
print(eigenvectors)
# Out:
# [[-0.00042662 -0.00240114 -0.00681031 ... -0.00042873  0.0022811
#    0.01085113]
#  [ 0.00333708 -0.00832499 -0.00391668 ... -0.0033604  -0.00070032
#    0.00105163]
#  [ 0.00725902  0.00401192 -0.00456556 ... -0.00179843 -0.01220611
#   -0.00104283]
#  [ 0.01019132 -0.00064115 -0.00095295 ...  0.0095454   0.01370144
#    0.0043609 ]
#  [ 0.0041367   0.00354933  0.00665366 ... -0.00879889 -0.00927068
#   -0.0027694 ]]

# %%
import numpy as np

location2 =r'C:\Users\Yash\OneDrive\Desktop\Nit Internship\Base paper Implementation\ssm_basis\sigma.npy'
data = np.load(location2)
sigma = data[:5]

# Print the array contents
print(sigma)
# Out:
# [1853.54425145  405.83531725  307.3041873   247.18201026  177.58565124]

# %%
p = np.array([
    -0.937466,
    -0.903766,
    -1.012244,
    -0.935772,
    0.967239
])

# %%
reconstructed_shape = mean_shape.copy()

# %%
for i in range(5):
    
    reconstructed_shape += (
        p[i]
        *
        sigma[i]
        *
        eigenvectors[i]
    )

# %%
vertices = reconstructed_shape.reshape(-1,3)

# %%
mesh = trimesh.Trimesh(
    vertices=vertices,
    faces=template_mesh.faces
)

# %%
mesh.export(
    "test_femur.stl"
)
# Out:
# b'N\xbe\x00\x00\xda\x92m\xbd\x1f\xc2\x1a\xbf\x86bK\xbfF\xa3\xa4C\xf75(Cp%?D\xcft\xa4C\xdfe\'C\xb8N?Di@\xa4C\x08\xf3\'C\xc85?D\x00\x00\t\xca\x10>~\xc3\x1b\xbf\x9a\xe8G\xbfF\xa3\xa4C\xf75(Cp%?D8\x1d\xa5C\x1c\xf9\'CU<?D\xfc\xd8\xa4C\x9fN\'C^W?D\x00\x00\xde\x1eq=\xbb\xf2"\xbf\x10\xdeD\xbf\xcft\xa4C\xdfe\'C\xb8N?DF\xa3\xa4C\xf75(Cp%?D\xfc\xd8\xa4C\x9fN\'C^W?D\x00\x00\xa2po>e\xb5%\xbfa\xb99\xbf\xfc\xd8\xa4C\x9fN\'C^W?D8\x1d\xa5C\x1c\xf9\'CU<?D\xf3:\xa5C\x07]\'C\xf0c?D\x00\x004l\x8e\xbe\x85b\x08\xbft\x9bL\xbfu,\xa4C\x0f\xe9(C\x00\x0c?D\x1f\xf5\xa3C1\x18(Cp8?D\x83\xcc\xa3C\xa2\x9d(CD)?D\x00\x00\xfe(J\xbe\x03\x93\x12\xbf\xb7\xb5K\xbfi@\xa4C\x08\xf3\'C\xc85?D\x1f\xf5\xa3C1\x18(Cp8?Du,\xa4C\x0f\xe9(C\x00\x0c?D\x00\x00\xdc\xf7\x9f\xbdo\x9e\x11\xbf\x13\x99Q\xbfi@\xa4C\x08\xf3\'C\xc85?Du,\xa4C\x0f\xe9(C\x00\x0c?DF\xa3\xa4C\xf75(Cp%?D\x00\x00\xbe*\x04\xbe\xa7 \x1d\xbf\x13cG\xbfF\xa3\xa4C\xf75(Cp%?Du,\xa4C\x0f\xe9(C\x00\x0c?D\x11\x9d\xa4Cn\x0b)C\xe6\xfb>D\x00\x006M\x0b>\xd7q\x1e\xbf[\tF\xbf8\x1d\xa5C\x1c\xf9\'CU<?DF\xa3\xa4C\xf75(Cp%?D\xdd\xfe\xa4C1\xbb(C\xd8\x12?D\x00\x00\x96z\xf7=C\xf9\x1a\xbf\x8cfI\xbf\xdd\xfe\xa4C1\xbb(C\xd8\x12?DF\xa3\xa4C\xf75(Cp%?D\x11\x9d\xa4Cn\x0b)C\xe6\xfb>D\x00\x00\xec4\xb5>\x1c\xaf\x18\xbf7n8\xbf\x1am\xa5C\xf1\xce\'C\xafX?D\xf3:\xa5C\x07]\'C\xf0c?D8\x1d\xa5C\x1c\xf9\'CU<?D\x00\x00\xd2\xe3\xd4>}\xed\xf9\xbe/qD\xbf\x1am\xa5C\xf1\xce\'C\xafX?D8\x1d\xa5C\x1c\xf9\'CU<?D\x01k\xa5C\xeax(C\x15=?D\x00\x00\x19\xfb\xdb>\xd4d\x01\xbfn\x8f?\xbf\x01k\xa5C\xeax(C\x15=?D8\x1d\xa5C\x1c\xf9\'CU<?D\xdd\xfe\xa4C1\xbb(C\xd8\x12?D\x00\x00\x84\xd3\x10?\t\xea\xe0\xbe\xa4\xa52\xbf\x1am\xa5C\xf1\xce\'C\xafX?D\x01k\xa5C\xeax(C\x15=?D1\xa6\xa5CX\x04(Ckg?D\x00\x00R\x93\x15\xbfo\xe8\x86\xbe\x94\x80D\xbff\xcd\xa3C\xec^)C\xad\x0f?D\xcb\x8c\xa3C\x0c\xc2(C\xba5?D\x92u\xa3C\x8cZ)C{1?D\x00\x00\xdc:\xdd\xbe\x82\x7f\xd6\xbe\x0erL\xbf\x83\xcc\xa3C\xa2\x9d(CD)?D\xcb\x8c\xa3C\x0c\xc2(C\xba5?Df\xcd\xa3C\xec^)C\xad\x0f?D\x00\x00\x0e%\xac\xbe\x06l\xe0\xbeidU\xbf\x83\xcc\xa3C\xa2\x9d(CD)?Df\xcd\xa3C\xec^)C\xad\x0f?Du,\xa4C\x0f\xe9(C\x00\x0c?D\x00\x00\xa2M\xba\xbe\xe3\xd2\xf9\xbe\x7f\x1dK\xbfu,\xa4C\x0f\xe9(C\x00\x0c?Df\xcd\xa3C\xec^)C\xad\x0f?D\t"\xa4C\xf0\xa8)C\xe4\xf0>D\x00\x00\xcf\x0c)\xbe\x95`\x01\xbf6\xd2X\xbf\x11\x9d\xa4Cn\x0b)C\xe6\xfb>Du,\xa4C\x0f\xe9(C\x00\x0c?D\xecu\xa4C\xaf\x94)C=\xeb>D\x00\x00\xfc\xc82\xbe@_\xff\xbe\xc5UY\xbf\xecu\xa4C\xaf\x94)C=\xeb>Du,\xa4C\x0f\xe9(C\x00\x0c?D\t"\xa4C\xf0\xa8)C\xe4\xf0>D\x00\x00r\xba\x81>\xdea\xc9\xbe~@b\xbf\xdd\xfe\xa4C1\xbb(C\xd8\x12?D\x11\x9d\xa4Cn\x0b)C\xe6\xfb>D\x1e\xdf\xa4C>k)C\xb5\xfa>D\x00\x00\xe0\xe9R>\xed\xdf\xa8\xbe\r\xdak\xbf\x1e\xdf\xa4C>k)C\xb5\xfa>D\x11\x9d\xa4Cn\x0b)C\xe6\xfb>D\xecu\xa4C\xaf\x94)C=\xeb>D\x00\x00j\x8b\x04?\xb7\x1c\xa7\xbefsJ\xbf\x01k\xa5C\xeax(C\x15=?D\xdd\xfe\xa4C1\xbb(C\xd8\x12?D\x8e:\xa5C\xd2$)C|\x1b?D\x00\x00\x1f\x07\xf9>l\xb7\x8e\xbe\xc2\xfdS\xbf\x8e:\xa5C\xd2$)C|\x1b?D\xdd\xfe\xa4C1\xbb(C\xd8\x12?D\x1e\xdf\xa4C>k)C\xb5\xfa>D\x00\x00\xab;&?A\xbf\xaa\xbe\xe6\xf7.\xbfU\xbb\xa5C.|(C\xd8b?D1\xa6\xa5CX\x04(Ckg?D\x01k\xa5C\xeax(C\x15=?D\x00\x00\xdb\xcd.?\xea\'\xc5\xbd\xb7e9\xbfU\xbb\xa5C.|(C\xd8b?D\x01k\xa5C\xeax(C\x15=?D\x14\x96\xa5Cm\x1c)C\xf4K?D\x00\x00\xf9\xda7?\xd6\xc1\x04\xbe\xe2\x04/\xbf\x14\x96\xa5Cm\x1c)C\xf4K?D\x01k\xa5C\xeax(C\x15=?D\x8e:\xa5C\xd2$)C|\x1b?D\x00\x00\xc6\xaf@? \x16\xd4\xbc}j(\xbfU\xbb\xa5C.|(C\xd8b?D\x14\x96\xa5Cm\x1c)C\xf4K?D~\xe7\xa5C\xbe\xc2(Ci{?D\x00\x00\xa81\x1b\xbfF\x10\xb4\xbd\xc8XJ\xbf\x87\xad\xa3C\xa3\xef)C\xe0\x17?Df\xcd\xa3C\xec^)C\xad\x0f?D\x92u\xa3C\x8cZ)C{1?D\x00\x00k\x12;\xbfa\'\xaa=Eu-\xbf\xccw\xa3C;\xea)C\xaf4?D\x87\xad\xa3C\xa3\xef)C\xe0\x17?D\x92u\xa3C\x8cZ)C{1?D\x00\x00\x84W\x15\xbf\xd2k\x8a\xbch\xe1O\xbf\t"\xa4C\xf0\xa8) ...
